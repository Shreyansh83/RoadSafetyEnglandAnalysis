# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('Casualty.csv')
data
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9696\2330437233.py:1: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Casualty.csv')
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 0                0  2019010128300           2019           10128300
# 1                1  2019010128300           2019           10128300
# 2                2  2019010128300           2019           10128300
# 3                3  2019010152270           2019           10152270
# 4                4  2019010155191           2019           10155191
# ...            ...            ...            ...                ...
# 139774      139774  2019552000254           2019          552000254
# 139775      139775  2019552000254           2019          552000254
# 139776      139776  2019552000270           2019          552000270
# 139777      139777  2019552000330           2019          552000330
# ...

# %% [raw]
# sns.displot(x='sex_of_casualty',data=data,palette='Accent')
#
# plt.show()

# %% [raw]
# a)	What patterns are there in the demographics of casualties?

# %%
res = data.groupby('casualty_class').count()
res
# Out:
#                 Unnamed: 0  accident_index  accident_year  accident_reference  \
# casualty_class
# 1                    91090           91090          91090               91090
# 2                    28915           28915          28915               28915
# 3                    19774           19774          19774               19774
#
#                 vehicle_reference  casualty_reference  sex_of_casualty  \
# casualty_class
# 1                           91090               91090            91090
# 2                           28915               28915            28915
# 3                           19774               19774            19774
#
#                 age_of_casualty  age_band_of_casualty  casualty_severity  \
# casualty_class
# 1                         91090                 91090              91090
# 2                         28915                 28915              28915
# 3                         19774                 19774              19774
#
# ...

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('Equal')

langs=('Driver','Passenger','Pedestrian')
count=[91090,28915,19774]

ax.pie(count,labels=langs, autopct='%1.2f%%')
plt.show()

# %%
res0 = data.groupby(['casualty_class','sex_of_casualty']).count()
res0
# Out:
#                                 Unnamed: 0  accident_index  accident_year  \
# casualty_class sex_of_casualty
# 1              1                     61338           61338          61338
#                2                     29752           29752          29752
# 2              1                     12048           12048          12048
#                2                     16867           16867          16867
# 3              1                     10928           10928          10928
#                2                      8846            8846           8846
#
#                                 accident_reference  vehicle_reference  \
# casualty_class sex_of_casualty
# 1              1                             61338              61338
#                2                             29752              29752
# 2              1                             12048              12048
#                2                             16867              16867
# ...

# %%
df = [[61338,12048,10928],[29752,16867,8846]]

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

x=np.arange(3)

ax.bar(x+0.0,df[0],color='m',width=0.5)
ax.bar(x+0.2,df[1],color='c',width=0.5)

ax.legend(labels=('Men','Women'))

ax.set_title('Comparision of men and women by casualty class')
ax.set_xticks(x,('Driver','Passenger','Pedestrian'))
ax.set_ylabel('No. of casualties')


plt.show()

# %%
d = data[data['casualty_class']==3]
d
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 5                5  2019010155192           2019           10155192
# 11              11  2019010155196           2019           10155196
# 19              19  2019010155209           2019           10155209
# 20              20  2019010155210           2019           10155210
# 21              21  2019010155216           2019           10155216
# ...            ...            ...            ...                ...
# 139758      139758  2019552000213           2019          552000213
# 139763      139763  2019552000220           2019          552000220
# 139769      139769  2019552000236           2019          552000236
# 139773      139773  2019552000253           2019          552000253
# 139778      139778  2019552000331           2019          552000331
#
#         vehicle_reference  casualty_reference  casualty_class  \
# 5                       1                   1               3
# ...

# %%
res1 = d.groupby('sex_of_casualty').count()
res1
# Out:
#                  Unnamed: 0  accident_index  accident_year  \
# sex_of_casualty
# 1                     10928           10928          10928
# 2                      8846            8846           8846
#
#                  accident_reference  vehicle_reference  casualty_reference  \
# sex_of_casualty
# 1                             10928              10928               10928
# 2                              8846               8846                8846
#
#                  casualty_class  age_of_casualty  age_band_of_casualty  \
# sex_of_casualty
# 1                         10928            10928                 10928
# 2                          8846             8846                  8846
#
#                  casualty_severity  pedestrian_location  pedestrian_movement  \
# sex_of_casualty
# 1                            10928                10928                10928
# 2                             8846                 8846                 8846
#
# ...

# %%
res11 = d.groupby('casualty_class').count()
res11
# Out:
#                 Unnamed: 0  accident_index  accident_year  accident_reference  \
# casualty_class
# 3                    19774           19774          19774               19774
#
#                 vehicle_reference  casualty_reference  sex_of_casualty  \
# casualty_class
# 3                           19774               19774            19774
#
#                 age_of_casualty  age_band_of_casualty  casualty_severity  \
# casualty_class
# 3                         19774                 19774              19774
#
#                 pedestrian_location  pedestrian_movement  car_passenger  \
# casualty_class
# 3                             19774                19774          19774
#
#                 bus_or_coach_passenger  pedestrian_road_maintenance_worker  \
# casualty_class
# 3                                19774                               19774
#
#                 casualty_type  casualty_home_area_type  casualty_imd_decile
# casualty_class
# ...

# %%
res3 = data.groupby(['age_band_of_casualty','casualty_type']).count()
res3
# Out:
#                                     Unnamed: 0  accident_index  accident_year  \
# age_band_of_casualty casualty_type
# 1                    0                     823             823            823
#                      1                      44              44             44
#                      4                       1               1              1
#                      8                      23              23             23
#                      9                    1361            1361           1361
# ...                                        ...             ...            ...
# 11                   21                      3               3              3
#                      22                     67              67             67
#                      23                      2               2              2
#                      37                      1               1              1
#                      90                      9               9              9
# ...

# %%
res31 = data[data['casualty_type']==1]
res31
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 4                4  2019010155191           2019           10155191
# 29              29  2019010155242           2019           10155242
# 38              38  2019010155282           2019           10155282
# 43              43  2019010155301           2019           10155301
# 49              49  2019010155306           2019           10155306
# ...            ...            ...            ...                ...
# 139702      139702  2019552000126           2019          552000126
# 139711      139711  2019552000150           2019          552000150
# 139732      139732  2019552000165           2019          552000165
# 139749      139749  2019552000179           2019          552000179
# 139765      139765  2019552000224           2019          552000224
#
#         vehicle_reference  casualty_reference  casualty_class  \
# 4                       2                   1               2
# ...

# %%
res4 = data[(data['casualty_type']==2)|(data['casualty_type']==3)|(data['casualty_type']==4)|(data['casualty_type']==5)|(data['casualty_type']==97)|(data['casualty_type']==103)|(data['casualty_type']==104)|(data['casualty_type']==105)|(data['casualty_type']==106)]
res4
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 25              25  2019010155225           2019           10155225
# 30              30  2019010155254           2019           10155254
# 36              36  2019010155263           2019           10155263
# 37              37  2019010155276           2019           10155276
# 39              39  2019010155284           2019           10155284
# ...            ...            ...            ...                ...
# 139748      139748  2019552000178           2019          552000178
# 139755      139755  2019552000197           2019          552000197
# 139766      139766  2019552000231           2019          552000231
# 139770      139770  2019552000237           2019          552000237
# 139777      139777  2019552000330           2019          552000330
#
#         vehicle_reference  casualty_reference  casualty_class  \
# 25                      2                   1               1
# ...

# %%
res41 = res4.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res41
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                     1
# 2                                     7
# 3                                    81
# 4                                  2583
# 5                                  2387
# 6                                  4042
# 7                                  2211
# 8                                  2020
# 9                                  1139
# 10                                  324
# 11                                   72

# %%
x2 = [1,7,81,2583,2387,4042,2211,2020,1139,324,72]

# %%
res31_1 = res31.groupby(['age_band_of_casualty','sex_of_casualty']).count()
#res31_1

# %%
#res31_12 = res31.groupby(['age_band_of_casualty','sex_of_casualty'])['sex_of_casualty'].sum()
#res31_12

# %%
res31_11 = res31.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res31_11
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                    44
# 2                                   303
# 3                                  1499
# 4                                  1174
# 5                                  1420
# 6                                  4029
# 7                                  2963
# 8                                  2579
# 9                                  1301
# 10                                  441
# 11                                  156

# %%
res5 = data[(data['casualty_type']==8)|(data['casualty_type']==108)]
res5
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 18              18  2019010155207           2019           10155207
# 23              23  2019010155220           2019           10155220
# 27              27  2019010155232           2019           10155232
# 58              58  2019010155351           2019           10155351
# 72              72  2019010155409           2019           10155409
# ...            ...            ...            ...                ...
# 139052      139052  2019551900825           2019          551900825
# 139073      139073  2019551900840           2019          551900840
# 139561      139561  2019551901241           2019          551901241
# 139639      139639  2019552000007           2019          552000007
# 139640      139640  2019552000007           2019          552000007
#
#         vehicle_reference  casualty_reference  casualty_class  \
# 18                      1                   1               1
# ...

# %%
res51 = res5.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res51
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                    23
# 2                                    22
# 3                                    34
# 4                                   103
# 5                                   169
# 6                                   592
# 7                                   502
# 8                                   442
# 9                                   223
# 10                                   70
# 11                                   32

# %%
x3=[23,22,34,103,169,592,502,442,223,70,32]

# %%
res6 = data[(data['casualty_type']==9)|(data['casualty_type']==109)]
res6
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 0                0  2019010128300           2019           10128300
# 1                1  2019010128300           2019           10128300
# 2                2  2019010128300           2019           10128300
# 3                3  2019010152270           2019           10152270
# 6                6  2019010155194           2019           10155194
# ...            ...            ...            ...                ...
# 139771      139771  2019552000237           2019          552000237
# 139772      139772  2019552000238           2019          552000238
# 139774      139774  2019552000254           2019          552000254
# 139775      139775  2019552000254           2019          552000254
# 139776      139776  2019552000270           2019          552000270
#
#         vehicle_reference  casualty_reference  casualty_class  \
# 0                       1                   1               1
# ...

# %%
res61 = res6.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res61
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                  1361
# 2                                  1910
# 3                                  1769
# 4                                  7926
# 5                                  9533
# 6                                 18877
# 7                                 11950
# 8                                 10470
# 9                                  6813
# 10                                 4228
# 11                                 3609

# %%
x4=[1361,1910,1769,7926,9533,18877,11950,10470,6813,4228,3609]

# %%
res7 = data[(data['casualty_type']==10)|(data['casualty_type']==11)|(data['casualty_type']==110)]
res7
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 44              44  2019010155302           2019           10155302
# 62              62  2019010155371           2019           10155371
# 63              63  2019010155371           2019           10155371
# 64              64  2019010155371           2019           10155371
# 65              65  2019010155371           2019           10155371
# ...            ...            ...            ...                ...
# 139555      139555  2019551901234           2019          551901234
# 139683      139683  2019552000059           2019          552000059
# 139697      139697  2019552000111           2019          552000111
# 139698      139698  2019552000111           2019          552000111
# 139714      139714  2019552000152           2019          552000152
#
#         vehicle_reference  casualty_reference  casualty_class  \
# 44                      1                   1               2
# ...

# %%
res71 = res7.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res71
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                   166
# 2                                    98
# 3                                   137
# 4                                   112
# 5                                   108
# 6                                   606
# 7                                   308
# 8                                   394
# 9                                   382
# 10                                  369
# 11                                  406

# %%
x5=[166,98,137,112,108,606,308,394,382,369,406]

# %%
res8 = data[data['casualty_type']==16]
#res6

# %%
res81 = res8.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res81
# Out:
#                       casualty_severity
# age_band_of_casualty
# 2                                     1
# 3                                     6
# 4                                    11
# 5                                     4
# 6                                     7
# 7                                     6
# 8                                    11
# 9                                     5
# 10                                    3

# %%
x6=[0,1,6,11,4,7,6,11,5,3,0]

# %%
res9 = data[data['casualty_type']==17]

# %%
res91 = res9.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res91
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                     2
# 3                                     2
# 4                                     6
# 5                                    12
# 6                                    12
# 7                                     8
# 8                                     9
# 9                                    13
# 10                                    6
# 11                                    4

# %%
x7=[2,0,2,6,12,12,8,9,13,6,4]

# %%
res10 = data[data['casualty_type']==18]

# %%
res100 = res10.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res100
# Out:
#                       casualty_severity
# age_band_of_casualty
# 6                                     2
# 7                                     1
# 8                                     1

# %%
x8 = [0,0,0,0,0,2,1,1,0,0,0]

# %%
res11 = data[(data['casualty_type']==20)|(data['casualty_type']==19)|(data['casualty_type']==21)|(data['casualty_type']==98)|(data['casualty_type']==113)]

# %%
res111 = res11.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res111
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                    19
# 2                                    25
# 3                                    28
# 4                                   151
# 5                                   408
# 6                                  1215
# 7                                   920
# 8                                   903
# 9                                   529
# 10                                  130
# 11                                   24

# %%
x9=[19,25,28,151,408,1215,920,903,529,130,24]

# %%
res12 = data[data['casualty_type']==22]

# %%
res121 = res12.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res121
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                     1
# 3                                     1
# 4                                     3
# 5                                     3
# 6                                    11
# 7                                     8
# 8                                    23
# 9                                    32
# 10                                   51
# 11                                   67

# %%
x10 = [1,0,1,3,3,11,8,23,32,51,67]

# %%
res13 = data[data['casualty_type']==23]

# %%
res123 = res13.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
res123
# Out:
#                       casualty_severity
# age_band_of_casualty
# 2                                     2
# 3                                     1
# 4                                     9
# 5                                     8
# 6                                    10
# 7                                    10
# 8                                     6
# 9                                     3
# 10                                    2
# 11                                    2

# %%
x11 = [0,2,1,9,8,10,10,6,3,2,2]

# %%
dd = data[(data['casualty_class']==3)]
dd
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 5                5  2019010155192           2019           10155192
# 11              11  2019010155196           2019           10155196
# 19              19  2019010155209           2019           10155209
# 20              20  2019010155210           2019           10155210
# 21              21  2019010155216           2019           10155216
# ...            ...            ...            ...                ...
# 139758      139758  2019552000213           2019          552000213
# 139763      139763  2019552000220           2019          552000220
# 139769      139769  2019552000236           2019          552000236
# 139773      139773  2019552000253           2019          552000253
# 139778      139778  2019552000331           2019          552000331
#
#         vehicle_reference  casualty_reference  casualty_class  \
# 5                       1                   1               3
# ...

# %%
df = dd[(dd['casualty_severity']==1)|(dd['casualty_severity']==2)]
df
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 5                5  2019010155192           2019           10155192
# 20              20  2019010155210           2019           10155210
# 22              22  2019010155217           2019           10155217
# 24              24  2019010155221           2019           10155221
# 85              85  2019010155452           2019           10155452
# ...            ...            ...            ...                ...
# 139750      139750  2019552000180           2019          552000180
# 139754      139754  2019552000196           2019          552000196
# 139758      139758  2019552000213           2019          552000213
# 139763      139763  2019552000220           2019          552000220
# 139778      139778  2019552000331           2019          552000331
#
#         vehicle_reference  casualty_reference  casualty_class  \
# 5                       1                   1               3
# ...

# %% [raw]
# c)	What patterns are there in pedestrians who were KSI casualties?

# %%
resa = df.groupby('sex_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
resa
# Out:
#                  casualty_severity
# sex_of_casualty
# 1                             3156
# 2                             2289

# %%
D = pd.DataFrame({'sex_of_casualty':['Male','Female'],'No.of_casualty':[3156,2289]})
D
# Out:
#   sex_of_casualty  No.of_casualty
# 0            Male            3156
# 1          Female            2289

# %%
sns.set_style('darkgrid')

sns.barplot(x='sex_of_casualty',y='No.of_casualty',data=D).set(title='Comparision by sex_of_casualty')
# Out:
# [Text(0.5, 1.0, 'Comparision by sex_of_casualty')]

# %%
d1 = df.groupby('age_band_of_casualty')[['casualty_severity']].agg(lambda x : x.astype(float).count())
d1
# Out:
#                       casualty_severity
# age_band_of_casualty
# 1                                   180
# 2                                   277
# 3                                   606
# 4                                   436
# 5                                   367
# 6                                   746
# 7                                   552
# 8                                   617
# 9                                   521
# 10                                  497
# 11                                  646

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

age = ['0-5','6-10','11-15','16-20','21-25','26-35','36-45','46-55','56-65','66-75','75+']
N = [180,277,606,436,367,746,552,617,521,497,646]

ax.bar(age,N)
ax.set_title('Pedestrian KSI casualty by age')
ax.set_xlabel('age_band of casualty')
ax.set_ylabel('No. of casualty')

plt.show()

# %%
d2 = df.groupby('casualty_home_area_type')[['casualty_severity']].agg(lambda x : x.astype(float).count())
d2
# Out:
#                          casualty_severity
# casualty_home_area_type
# 1                                     4897
# 2                                      281
# 3                                      267

# %%
count=(4897,281,267)
langs=('Urban Area','Small Town','Rural Area')
color = ['#ff9999','#66b3ff','#99ff99']

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('Equal')


ax.pie(count,labels=langs,colors=color,autopct='%1.2f%%')
ax.set_title('Pedestrian KSI Casualties by home_area_type')
plt.show()

# %%
sns.heatmap(d2,annot=True,vmin=0,vmax=4897)
plt.show()

# %%
d3 = df.groupby('casualty_imd_decile')[['casualty_severity']].agg(lambda x : x.astype(float).count())
d3
# Out:
#                      casualty_severity
# casualty_imd_decile
# 1                                  763
# 2                                 1366
# 3                                  609
# 4                                  534
# 5                                  443
# 6                                  426
# 7                                  368
# 8                                  335
# 9                                  317
# 10                                 284

# %%
langs=('Max Deprived 10%','max 10-20%','max 20-30%','max 30-40%','max 40-50%','min 40-50%','min 30-40%','min 20-30%','10-20%','least deprived 10%')
count=(763,1366,609,534,443,426,368,335,317,284)

fig1,ax1 = plt.subplots()

ax1.pie(count,labels=langs, autopct='%1.2f%%')
ax1.set_title('                     Pedestrian KSI by IMD decile')

centre_circle =plt.Circle((0,0),0.75,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

ax1.axis('equal')
plt.tight_layout()
plt.show()

# %%
d4 = df.groupby('casualty_type')[['casualty_severity']].agg(lambda x : x.astype(float).count())
d4
# Out:
#                casualty_severity
# casualty_type
# 0                           5445
